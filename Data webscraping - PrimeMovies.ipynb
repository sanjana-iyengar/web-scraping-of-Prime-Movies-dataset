# %% [markdown]
# ## Amazon Prime -  Movies

# %%
import pandas as pd # library for data analysis
import requests # library to handle requests
from bs4 import BeautifulSoup # library to parse HTML documents

# %%
# get the response in the form of html
wikiurl="https://www.finder.com/in/amazon-prime-movies"
table_class="custom-table js-tablesorter custom-table--responsive tablesorter tablesorter-default"
response=requests.get(wikiurl)
print(response.status_code)
# Out:
# 200

# %%
# parse data from the html into a beautifulsoup object
soup = BeautifulSoup(response.text, 'html.parser')
indiatable=soup.find('table',{'class':"custom-table"})

# %%
df=pd.read_html(str(indiatable))
# convert list to dataframe
df=pd.DataFrame(df[0])

# %%
df
# Out:
#                                                    Name  IMDB Rating Duration  \
# 0                                  The Legend of Tarzan          6.3  109 min
# 1                                       The Conjuring 2          7.4  133 min
# 2                                             Anomalisa          7.3   90 min
# 3                                 Baghtos Kay Mujra Kar          8.8  141 min
# 4             13 Hours: The Secret Soldiers of Benghazi          7.3  144 min
# ...                                                 ...          ...      ...
# 4644  Five Little Fingers, Finger Family Song and Ma...          NaN   65 min
# 4645  Five Little Monkeys Jumping On The Bed and Man...          NaN  100 min
# 4646  Wheels on the Bus – Wild Animals and Animal So...          NaN   91 min
# 4647  If You’re Happy And You Know It and More Video...          NaN   77 min
# 4648  Johny Johny Yes Papa PART 2 and Many More Vide...          NaN   74 min
#
# ...

# %%
df.to_csv(r'C:\Users\Sanjana\Documents\OTT analysis\prime_movies.csv')
